# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12729095520","type":"CreateEvent","actor":{"id":58561319,"login":"cjxd-bot-test","display_login":"cjxd-bot-test","gravatar_id":"","url":"https://api.github.com/users/cjxd-bot-test","avatar_url":"https://avatars.githubusercontent.com/u/58561319?"},"repo":{"id":274831196,"name":"cb-kubecd/bdd-gh-1593054895","url":"https://api.github.com/repos/cb-kubecd/bdd-gh-1593054895"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-06-25T04:47:56Z","org":{"id":43623793,"login":"cb-kubecd","gravatar_id":"","url":"https://api.github.com/orgs/cb-kubecd","avatar_url":"https://avatars.githubusercontent.com/u/43623793?"}},{"id":"12729095512","type":"CreateEvent","actor":{"id":3042012,"login":"francisk","display_login":"francisk","gravatar_id":"","url":"https://api.github.com/users/francisk","avatar_url":"https://avatars.githubusercontent.com/u/3042012?"},"repo":{"id":257499279,"name":"francisk/autoco
# ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '12729095520',
#   'type': 'CreateEvent',
#   'actor': {'id': 58561319,
#    'login': 'cjxd-bot-test',
#    'display_login': 'cjxd-bot-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cjxd-bot-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58561319?'},
#   'repo': {'id': 274831196,
#    'name': 'cb-kubecd/bdd-gh-1593054895',
#    'url': 'https://api.github.com/repos/cb-kubecd/bdd-gh-1593054895'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-06-25T04:47:56Z',
#   'org': {'id': 43623793,
#    'login': 'cb-kubecd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cb-kubecd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43623793?'}},
#  {'id': '12729095512',
#   'type': 'CreateEvent',
#   'actor': {'id': 3042012,
#    'login': 'francisk',
# ...

# %%
import json
import requests
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'all': [{'_id': '599f87db9a11040c4a16343f',
#    'text': 'The goddess of love, beauty, and fertility in Norse mythology, Freyja was the first cat lady. She is depicted in stories as riding a chariot that was drawn by cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5894af975cdc7400113ef7f9',
#    'text': 'The technical term for a cat’s hairball is a bezoar.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b0c5e3e7ab3c50014df65fe',
#    'text': 'People who own cats have on average 2.1 pets per household, where dog owners have about 1.6.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
# ...
